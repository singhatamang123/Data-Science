# %%
import numpy as np
import pandas as pd

# %%
data_set_01 = pd.read_csv('Data_Set.csv')
data_set_01
# Out:
#    Name of the data = Home Consumption Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                   Unit = kW and $/kW        NaN        NaN        NaN
# 1                                 Time     E_Plug     E_Heat      Price
# 2                                    1         24         28         10
# 3                                    2         17         32         12
# 4                                    3         16         34         11
# 5                                    3         16         34         11
# 6                                    4         16         33         12
# 7                                    5         16         30         10
# 8                                    6         16         31         10
# 9                                    7         19         28         14
# 10                                   8         22         29         12
# 11                                   9         25         26         12
# ...

# %%
data_set_01.head()
# Out:
#   Name of the data = Home Consumption Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                  Unit = kW and $/kW        NaN        NaN        NaN
# 1                                Time     E_Plug     E_Heat      Price
# 2                                   1         24         28         10
# 3                                   2         17         32         12
# 4                                   3         16         34         11
#
#     Unnamed: 4     Unnamed: 5
# 0          NaN            NaN
# 1  Temperature  No. Occupants
# 2          -15             12
# 3          -17             12
# 4          -19             12

# %%
data_set_01.shape
# Out:
# (27, 6)

# %%
data_set_01.tail()
# Out:
#    Name of the data = Home Consumption Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 22                                  20        120         33         21
# 23                                  21         47         32         21
# 24                                  22         44         30         22
# 25                                  23         36         35          !
# 26                                  24         37         36         18
#
#    Unnamed: 4 Unnamed: 5
# 22        -12         12
# 23        -16         12
# 24        -18         12
# 25        -19         12
# 26        -22         12

# %%
data_set_02 = pd.read_csv('Data_Set.csv', header=2)
data_set_02.head()
# Out:
#    Time  E_Plug  E_Heat Price  Temperature  No. Occupants
# 0     1    24.0      28    10          -15             12
# 1     2    17.0      32    12          -17             12
# 2     3    16.0      34    11          -19             12
# 3     3    16.0      34    11          -19             12
# 4     4    16.0      33    12          -18             12

# %%
data_set_03 = data_set_02.rename(columns={'Temperature': 'temp'})
data_set_03.head()
# Out:
#    Time  E_Plug  E_Heat Price  temp  No. Occupants
# 0     1    24.0      28    10   -15             12
# 1     2    17.0      32    12   -17             12
# 2     3    16.0      34    11   -19             12
# 3     3    16.0      34    11   -19             12
# 4     4    16.0      33    12   -18             12

# %%
data_set_03.drop('No. Occupants', axis=1, inplace=True)
data_set_03.head()
# Out:
#    Time  E_Plug  E_Heat Price  temp
# 0     1    24.0      28    10   -15
# 1     2    17.0      32    12   -17
# 2     3    16.0      34    11   -19
# 3     3    16.0      34    11   -19
# 4     4    16.0      33    12   -18

# %% [markdown]
# ## Machine learning steps
#
# Step 1: Data collection (kaggle, web Scraping --> Beautiful Soup, Selenimum)
# Step 2: Data  preparation / Data preproccessing
# Step 3: Choose a model (linear Regression , logistic Regression)
# Step 4:  Train out model
# Step 5: Evaluate the model
# Step 6: Parameter Tunning / Hyperparameter Tuning
# Step 7: Predictions

# %%
data_set_03.iloc[10:15]
# Out:
#     Time  E_Plug  E_Heat Price  temp
# 10    10    26.0      24    14    -8
# 11    11    27.0      20    14    -4
# 12    12    30.0      19    16     0
# 13    13    30.0      19    16     0
# 14    14     NaN      13    17     2

# %%
type(data_set_03)
# Out:
# pandas.core.frame.DataFrame

# %%
dup_data = data_set_03[data_set_03.duplicated()]
dup_data
# Out:
#    Time  E_Plug  E_Heat Price  temp
# 3     3    16.0      34    11   -19

# %%
data_set_04 = data_set_03.drop(3, axis=0)
data_set_04.head()
# Out:
#    Time  E_Plug  E_Heat Price  temp
# 0     1    24.0      28    10   -15
# 1     2    17.0      32    12   -17
# 2     3    16.0      34    11   -19
# 4     4    16.0      33    12   -18
# 5     5    16.0      30    10   -14

# %%
data_set_04.reset_index(drop=True).head()
# Out:
#    Time  E_Plug  E_Heat Price  temp
# 0     1    24.0      28    10   -15
# 1     2    17.0      32    12   -17
# 2     3    16.0      34    11   -19
# 3     4    16.0      33    12   -18
# 4     5    16.0      30    10   -14

# %% [markdown]
# ## Describe Method

# %%
data_set_04.describe()
# Out:
#             Time      E_Plug     E_Heat       temp
# count  24.000000   23.000000  24.000000  24.000000
# mean   12.500000   31.521739  25.666667 -10.250000
# std     7.071068   21.336843   9.262672   7.968689
# min     1.000000   16.000000  -4.000000 -22.000000
# 25%     6.750000   20.500000  19.750000 -16.250000
# 50%    12.500000   27.000000  28.500000 -13.000000
# 75%    18.250000   34.500000  32.000000  -3.000000
# max    24.000000  120.000000  36.000000   3.000000

# %% [markdown]
# ## Spot Negative number of E Heat Column

# %%
minimu_otem = data_set_04['E_Heat'].min()
minimu_otem

data_set_04
# Out:
#     Time  E_Plug  E_Heat Price  temp
# 0      1    24.0      28    10   -15
# 1      2    17.0      32    12   -17
# 2      3    16.0      34    11   -19
# 4      4    16.0      33    12   -18
# 5      5    16.0      30    10   -14
# 6      6    16.0      31    10   -16
# 7      7    19.0      28    14   -14
# 8      8    22.0      29    12   -15
# 9      9    25.0      26    12   -12
# 10    10    26.0      24    14    -8
# 11    11    27.0      20    14    -4
# 12    12    30.0      19    16     0
# 13    13    30.0      19    16     0
# 14    14     NaN      13    17     2
# 15    15    27.0      14    17     3
# 16    16    27.0      16    17     2
# 17    17    28.0      -4    18     0
# 18    18    33.0      26    20    -6
# 19    19    42.0      32    21    -8
# 20    20   120.0      33    21   -12
# 21    21    47.0      32    21   -16
# 22    22    44.0      30    22   -18
# 23    23    36.0      35     !   -19
# 24    24    37.0      36    18   -22

# %% [markdown]
# ## Locat Min Item

# %%
data_set_04['E_Heat'][data_set_04['E_Heat'] ==minimu_otem]
# Out:
# 17   -4
# Name: E_Heat, dtype: int64

# %%
data_set_04['E_Heat'] = data_set_04['E_Heat'].replace(-4,4)
data_set_04.head()
# Out:
#    Time  E_Plug  E_Heat Price  temp
# 0     1    24.0      28    10   -15
# 1     2    17.0      32    12   -17
# 2     3    16.0      34    11   -19
# 4     4    16.0      33    12   -18
# 5     5    16.0      30    10   -14

# %%
data_set_04.cov()
# Out:
#              Time      E_Plug     E_Heat       temp
# Time    50.000000   88.535573  -3.826087   8.217391
# E_Plug  88.535573  455.260870  28.555336   0.154150
# E_Heat  -3.826087   28.555336  67.826087 -58.782609
# temp     8.217391    0.154150 -58.782609  63.500000

# %%
import seaborn as sns
sns.heatmap(data_set_04.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Missing Values

# %%
# 1. Just drop the rows
# 2. Create the sub-model
# 3. Imputer with mean, medain, node

# %%
data_set_04.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24 entries, 0 to 24
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    24 non-null     int64
#  1   E_Plug  23 non-null     float64
#  2   E_Heat  24 non-null     int64
#  3   Price   24 non-null     object
#  4   temp    24 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.1+ KB

# %%
data_set_04['Price'] = data_set_04['Price'].replace('!', np.NaN)
data_set_04.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24 entries, 0 to 24
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    24 non-null     int64
#  1   E_Plug  23 non-null     float64
#  2   E_Heat  24 non-null     int64
#  3   Price   23 non-null     object
#  4   temp    24 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.1+ KB

# %%
data_set_04['Price'] = data_set_04['Price'].apply(pd.to_numeric)
data_set_04.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24 entries, 0 to 24
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    24 non-null     int64
#  1   E_Plug  23 non-null     float64
#  2   E_Heat  24 non-null     int64
#  3   Price   23 non-null     float64
#  4   temp    24 non-null     int64
# dtypes: float64(2), int64(3)
# memory usage: 1.1 KB

# %%
data_set_04.isna().sum()
# Out:
# Time      0
# E_Plug    1
# E_Heat    0
# Price     1
# temp      0
# dtype: int64

# %%
data_set_04.fillna(method ='bfill')

#bfill --> backward fill
# ffill --. forward fill
# Out:
#     Time  E_Plug  E_Heat  Price  temp
# 0      1    24.0      28   10.0   -15
# 1      2    17.0      32   12.0   -17
# 2      3    16.0      34   11.0   -19
# 4      4    16.0      33   12.0   -18
# 5      5    16.0      30   10.0   -14
# 6      6    16.0      31   10.0   -16
# 7      7    19.0      28   14.0   -14
# 8      8    22.0      29   12.0   -15
# 9      9    25.0      26   12.0   -12
# 10    10    26.0      24   14.0    -8
# 11    11    27.0      20   14.0    -4
# 12    12    30.0      19   16.0     0
# 13    13    30.0      19   16.0     0
# 14    14    27.0      13   17.0     2
# 15    15    27.0      14   17.0     3
# 16    16    27.0      16   17.0     2
# 17    17    28.0       4   18.0     0
# 18    18    33.0      26   20.0    -6
# 19    19    42.0      32   21.0    -8
# 20    20   120.0      33   21.0   -12
# 21    21    47.0      32   21.0   -16
# 22    22    44.0      30   22.0   -18
# 23    23    36.0      35   18.0   -19
# 24    24    37.0      36   18.0   -22

# %% [markdown]
# ## Impute with mean , medain and mode

# %%
data_set_04.isna().sum()
# Out:
# Time      0
# E_Plug    1
# E_Heat    0
# Price     1
# temp      0
# dtype: int64

# %%
data_set_04.boxplot()  ## checking  outlier
# Out:
# <AxesSubplot:>

# %%
data_set_04['E_Plug'].fillna((data_set_04['E_Plug'].median()), inplace= True)
data_set_04
# Out:
#     Time  E_Plug  E_Heat  Price  temp
# 0      1    24.0      28   10.0   -15
# 1      2    17.0      32   12.0   -17
# 2      3    16.0      34   11.0   -19
# 4      4    16.0      33   12.0   -18
# 5      5    16.0      30   10.0   -14
# 6      6    16.0      31   10.0   -16
# 7      7    19.0      28   14.0   -14
# 8      8    22.0      29   12.0   -15
# 9      9    25.0      26   12.0   -12
# 10    10    26.0      24   14.0    -8
# 11    11    27.0      20   14.0    -4
# 12    12    30.0      19   16.0     0
# 13    13    30.0      19   16.0     0
# 14    14    27.0      13   17.0     2
# 15    15    27.0      14   17.0     3
# 16    16    27.0      16   17.0     2
# 17    17    28.0       4   18.0     0
# 18    18    33.0      26   20.0    -6
# 19    19    42.0      32   21.0    -8
# 20    20   120.0      33   21.0   -12
# 21    21    47.0      32   21.0   -16
# 22    22    44.0      30   22.0   -18
# 23    23    36.0      35    NaN   -19
# 24    24    37.0      36   18.0   -22

# %%
data_set_04['Price'].fillna((data_set_04['Price'].mean()), inplace= True)
data_set_04
# Out:
#     Time  E_Plug  E_Heat      Price  temp
# 0      1    24.0      28  10.000000   -15
# 1      2    17.0      32  12.000000   -17
# 2      3    16.0      34  11.000000   -19
# 4      4    16.0      33  12.000000   -18
# 5      5    16.0      30  10.000000   -14
# 6      6    16.0      31  10.000000   -16
# 7      7    19.0      28  14.000000   -14
# 8      8    22.0      29  12.000000   -15
# 9      9    25.0      26  12.000000   -12
# 10    10    26.0      24  14.000000    -8
# 11    11    27.0      20  14.000000    -4
# 12    12    30.0      19  16.000000     0
# 13    13    30.0      19  16.000000     0
# 14    14    27.0      13  17.000000     2
# 15    15    27.0      14  17.000000     3
# 16    16    27.0      16  17.000000     2
# 17    17    28.0       4  18.000000     0
# 18    18    33.0      26  20.000000    -6
# 19    19    42.0      32  21.000000    -8
# 20    20   120.0      33  21.000000   -12
# 21    21    47.0      32  21.000000   -16
# ...

# %%
data_set_04
# Out:
#     Time  E_Plug  E_Heat      Price  temp
# 0      1    24.0      28  10.000000   -15
# 1      2    17.0      32  12.000000   -17
# 2      3    16.0      34  11.000000   -19
# 4      4    16.0      33  12.000000   -18
# 5      5    16.0      30  10.000000   -14
# 6      6    16.0      31  10.000000   -16
# 7      7    19.0      28  14.000000   -14
# 8      8    22.0      29  12.000000   -15
# 9      9    25.0      26  12.000000   -12
# 10    10    26.0      24  14.000000    -8
# 11    11    27.0      20  14.000000    -4
# 12    12    30.0      19  16.000000     0
# 13    13    30.0      19  16.000000     0
# 14    14    27.0      13  17.000000     2
# 15    15    27.0      14  17.000000     3
# 16    16    27.0      16  17.000000     2
# 17    17    28.0       4  18.000000     0
# 18    18    33.0      26  20.000000    -6
# 19    19    42.0      32  21.000000    -8
# 20    20   120.0      33  21.000000   -12
# 21    21    47.0      32  21.000000   -16
# ...

# %%
data_set_04['E_Plug'].replace(120, data_set_04['E_Plug'].mean(), inplace=True)

# %%
data_set_04.boxplot()
# Out:
# <AxesSubplot:>
